# %%
import pandas as pd

# %%
df=pd.read_csv('marks.csv')

# %%
df
# Out:
#     narmada   40   50   60
# 0    nethra   50   78   83
# 1    mythri  626  963  293
# 2   lalitha   67  385   36
# 3  gayathri   36   85  875
# 4    chandu  636   85  923

# %%
df=pd.read_csv('marks.csv',header=None)
df
# Out:
#           0    1    2    3
# 0   narmada   40   50   60
# 1    nethra   50   78   83
# 2    mythri  626  963  293
# 3   lalitha   67  385   36
# 4  gayathri   36   85  875
# 5    chandu  636   85  923

# %%
df.columns=['name','telugu','hindi','eng']
df
# Out:
#        name  telugu  hindi  eng
# 0   narmada      40     50   60
# 1    nethra      50     78   83
# 2    mythri     626    963  293
# 3   lalitha      67    385   36
# 4  gayathri      36     85  875
# 5    chandu     636     85  923

# %%
df=pd.read_csv('marks.csv',names=['name','telugu','hindi','eng'])
df
# Out:
#        name  telugu  hindi  eng
# 0   narmada      40     50   60
# 1    nethra      50     78   83
# 2    mythri     626    963  293
# 3   lalitha      67    385   36
# 4  gayathri      36     85  875
# 5    chandu     636     85  923

# %%
df.to_csv('marks.csv',columns=['name','telugu','hindi','eng'],index=False)
df
# Out:
#        name  telugu  hindi  eng
# 0   narmada      40     50   60
# 1    nethra      50     78   83
# 2    mythri     626    963  293
# 3   lalitha      67    385   36
# 4  gayathri      36     85  875
# 5    chandu     636     85  923

# %%
df.set_index('name')
# Out:
#           telugu  hindi  eng  Total
# name
# narmada       40     50   60    150
# nethra        50     78   83    211
# mythri       626    963  293   1882
# lalitha       67    385   36    488
# gayathri      36     85  875    996
# chandu       636     85  923   1644

# %%
df.sum(axis=0)
# Out:
# name      narmadanethramythrilalithagayathrichandu
# telugu                                        1455
# hindi                                         1646
# eng                                           2270
# Total                                         5371
# dtype: object

# %%
df['Total']=df.sum(axis=1)
df
# Out:
#        name  telugu  hindi  eng  Total
# 0   narmada      40     50   60    300
# 1    nethra      50     78   83    422
# 2    mythri     626    963  293   3764
# 3   lalitha      67    385   36    976
# 4  gayathri      36     85  875   1992
# 5    chandu     636     85  923   3288

# %%
df[['name','telugu']]
# Out:
#        name  telugu
# 0   narmada      40
# 1    nethra      50
# 2    mythri     626
# 3   lalitha      67
# 4  gayathri      36
# 5    chandu     636

# %%
df[df['name']=='nethra']
# Out:
#      name  telugu  hindi  eng  Total
# 1  nethra      50     78   83    422

# %%
df.drop(0)
# Out:
#        name  telugu  hindi  eng  Total
# 1    nethra      50     78   83    422
# 2    mythri     626    963  293   3764
# 3   lalitha      67    385   36    976
# 4  gayathri      36     85  875   1992
# 5    chandu     636     85  923   3288

# %%
sdata={'ohio':3500,'Texas':738973,'oregeon':6563736}
obj3=pd.Series(sdata)
obj3
# Out:
# ohio          3500
# Texas       738973
# oregeon    6563736
# dtype: int64

# %%
obj4=['califonia','gsytyg','hsyfgsy']
obj5=pd.Series(obj3,index=obj4)
obj5
# Out:
# califonia   NaN
# gsytyg      NaN
# hsyfgsy     NaN
# dtype: float64

# %%
data={'state':[]}

# %%
obj=pd.Series([4.5,7.2,-5.3,3.6],index=['d','b','a','c'])
obj
# Out:
# d    4.5
# b    7.2
# a   -5.3
# c    3.6
# dtype: float64

# %%
obj2=obj.reindex(['a','b','c','d','e'])
obj2
# Out:
# a   -5.3
# b    7.2
# c    3.6
# d    4.5
# e    NaN
# dtype: float64

# %%
obj2.drop('a')
# Out:
# b    7.2
# c    3.6
# d    4.5
# e    NaN
# dtype: float64

# %%
obj=pd.Series([7,-5,7,4,2,0,4])
obj.rank()
# Out:
# 0    6.5
# 1    1.0
# 2    6.5
# 3    4.5
# 4    3.0
# 5    2.0
# 6    4.5
# dtype: float64

# %%
df
# Out:
#        name  telugu  hindi  eng  Total
# 0   narmada      40     50   60    300
# 1    nethra      50     78   83    422
# 2    mythri     626    963  293   3764
# 3   lalitha      67    385   36    976
# 4  gayathri      36     85  875   1992
# 5    chandu     636     85  923   3288

# %%
sf=pd.read_csv("student.csv")
sf
# Out:
#        name branch
# 0   narmada    ece
# 1    nethra    eee
# 2    mythri    ece
# 3   lalitha    eee
# 4  gayathri   mech

# %%
pd.merge(df,sf)
# Out:
#        name  telugu  hindi  eng  Total branch
# 0   narmada      40     50   60    300    ece
# 1    nethra      50     78   83    422    eee
# 2    mythri     626    963  293   3764    ece
# 3   lalitha      67    385   36    976    eee
# 4  gayathri      36     85  875   1992   mech

# %%
pd.merge(df,sf,on='name',how='left')
# Out:
#        name  telugu  hindi  eng  Total branch
# 0   narmada      40     50   60    300    ece
# 1    nethra      50     78   83    422    eee
# 2    mythri     626    963  293   3764    ece
# 3   lalitha      67    385   36    976    eee
# 4  gayathri      36     85  875   1992   mech
# 5    chandu     636     85  923   3288    NaN
